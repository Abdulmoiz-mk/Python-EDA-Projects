# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdulmoiz-mk/Python-EDA-Projects/blob/main/Cars_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Place the Google Drive Sharing link\n",
file_share_link = "https://drive.google.com/file/d/1kwyrV47FesxdKYyPrPg8KxdbY6Q07OQY/view?usp=sharing"
# extract the ID of the file
file_id = file_share_link[file_share_link.find("d/")+2 : file_share_link.find("/v")]
print(file_id)
# !gdown "$file_id" # Download the data from Google Drive"
# Out:
# 1kwyrV47FesxdKYyPrPg8KxdbY6Q07OQY
# Downloading...
# From: https://drive.google.com/uc?id=1kwyrV47FesxdKYyPrPg8KxdbY6Q07OQY
# To: /content/Cars.csv
# 100% 25.3k/25.3k [00:00<00:00, 58.1MB/s]

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("Cars.csv")
df.head()
# Out:
#                     carname fueltype aspiration doornumber      carbody  \
# 0        alfa-romero giulia      gas        std        two  convertible
# 1       alfa-romero stelvio      gas        std        two  convertible
# 2  alfa-romero Quadrifoglio      gas        std        two    hatchback
# 3               audi 100 ls      gas        std       four        sedan
# 4                audi 100ls      gas        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  carwidth  ...  enginesize  \
# 0        rwd          front       88.6      168.8      64.1  ...       130.0
# 1        rwd          front       88.6      168.8      64.1  ...       130.0
# 2        rwd          front       94.5      171.2      65.5  ...       152.0
# 3        fwd          front       99.8      176.6      66.2  ...       109.0
# 4        4wd          front       99.4      176.6      66.4  ...       136.0
#
# ...

# %%
df['carbody'].value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
#Marginal Probability
e = 96
s =df['carbody'].value_counts().sum()
p = e/s
p
# Out:
# 0.4682926829268293

# %%
#Finding joint probability
pd.crosstab(df['carbody'], df['fueltype'], margins=True)
# Out:
# fueltype     diesel  gas  All
# carbody
# convertible       0    6    6
# hardtop           1    7    8
# hatchback         1   69   70
# sedan            15   81   96
# wagon             3   22   25
# All              20  185  205

# %%
e = 81
p = e/s
p
# Out:
# 0.3951219512195122

# %%
#What is the probab that a car is sedan given it is a gas fuel type (Conditional probability)
# P(A|B) = P(AnB)/P(B)

P_AnB = 81
P_B = 185
P_A_B = 81/185
print(f'probab that a car is sedan given it is a gas fuel type is {P_A_B}')
# Out:
# probab that a car is sedan given it is a gas fuel type is 0.43783783783783786
